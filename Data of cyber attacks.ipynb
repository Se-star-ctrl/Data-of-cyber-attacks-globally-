# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sb

# %%
df = pd.read_excel( r"C:\Users\DELL\Downloads\project\all_recs.xlsx")
df
# Out:
#                       Date                    Location  \
# 0               31/12/2022  Iran (Islamic Republic of)
# 1               31/12/2022    United States of America
# 2               30/12/2022                      Poland
# 3               30/12/2022    United States of America
# 4               30/12/2022  Iran (Islamic Republic of)
# ...                    ...                         ...
# 10415  2014-03-01 00:00:00    United States of America
# 10416  2014-03-01 00:00:00    United States of America
# 10417  2014-03-01 00:00:00                    Malaysia
# 10418  2014-03-01 00:00:00    United States of America
# 10419  2014-03-01 00:00:00                   Australia
#
#                                                   Victim  \
# 0                             State-run Iranian Websites
# 1      Housing Authority of the City of Los Angeles (...
# 2                                      Polish Parliament
# 3                          CentraState Healthcare System
# 4                                          Iran Airlines
# ...                                                  ...
# 10415                                         Battle.net
# 10416                                             Origin
# 10417                    Malaysian Ministry of Education
# 10418                                              Steam
# 10419                          Financial Services Online
#
#                                 Industry      Actor Location  \
# 0                  Public Administration        Undetermined
# 1                  Public Administration        Undetermined
# 2                  Public Administration  Russian Federation
# 3      Health Care and Social Assistance        Undetermined
# 4         Transportation and Warehousing             Ukraine
# ...                                  ...                 ...
# 10415                        Information        Undetermined
# 10416                        Information        Undetermined
# 10417              Public Administration        Undetermined
# 10418                        Information        Undetermined
# 10419              Finance and Insurance            Pakistan
#
#                    Actor        Motive          Type  \
# 0           Undetermined       Protest    Disruptive
# 1            LockBit 3.0     Financial  Exploitative
# 2          NoName057(16)       Protest    Disruptive
# 3           Undetermined  Undetermined    Disruptive
# 4        rootkitsecurity       Protest    Disruptive
# ...                  ...           ...           ...
# 10415      DERP Trolling  Undetermined    Disruptive
# 10416      DERP Trolling  Undetermined    Disruptive
# 10417   Evil Shadow Team  Undetermined    Disruptive
# 10418       Undetermined  Undetermined    Disruptive
# 10419  Pakiz Cyber Squad  Undetermined    Exploitive
#
#                                  Sub-Type    Year
# 0             External Denial of Services  2022.0
# 1                            Undetermined  2022.0
# 2             External Denial of Services  2022.0
# 3                            Undetermined  2022.0
# 4             External Denial of Services  2022.0
# ...                                   ...     ...
# 10415          External Denial of Service  2014.0
# 10416          External Denial of Service  2014.0
# 10417                Message Manipulation  2014.0
# 10418          External Denial of Service  2014.0
# 10419  Exploitation of Application Server  2014.0
#
# [10420 rows x 10 columns]

# %%
year_order = df['Year'].value_counts().index
location_order = df['Location'].value_counts().index
motive_order = df['Motive'].value_counts().index
industry_order = df['Industry'].value_counts().index

# %%
#attack frequency by year
plt.figure(figsize=[20,8])
plt.title("Attack Frequency by year")
sb.countplot(data=df, y='Year', color=sb.color_palette()[2],
             order=year_order)
plt.xticks(rotation=15);

# %%
#Attack frequency by industry
plt.figure(figsize=(20,8))
plt.title("Attack Frequency by Industry")
sb.countplot(data=df, y= 'Industry', color=sb.color_palette()[2],
             order= industry_order)
plt.xticks(rotation=45);

# %%
#Attack frequency by motive
motive_order = df['Motive'].value_counts().index
plt.figure(figsize=[20,8])
plt.title("Attack Frequency by Motive")
sb.countplot(data=df, y='Motive', color=sb.color_palette()[2],
             order=motive_order)
plt.xticks(rotation=15);

# %%
#Attack frequency by location
location_order = df['Location'].value_counts().index
plt.figure(figsize=[10,30])
plt.title("Attack Frequency by Location")
sb.countplot(data=df, y='Location', color=sb.color_palette()[3],
             order=location_order)
plt.xticks(rotation=15);
